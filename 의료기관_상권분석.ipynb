# %% [markdown]
# ## 1.1 세팅

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 1.2 시각화를 위한 폰트 설정

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')

# %matplotlib inline

# %%
ls
# Out:
# (필독) 일반사용자 파일 열람 방법.hwp
# 19년도 소상공인 상가상권 데이터분석.ipynb
# 201101 전국 신규 민간 아파트 분양가 분석.ipynb
# jupyter basic.ipynb
# practice1.ipynb
# seoul_municipalities_geo_simple.json
# 전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv
# 의료기관_상권분석.ipynb
# 상가업소정보_201912_01.csv
# 주택도시보증공사_전국 평균 분양가격(2019년 12월).csv
# 전국도시공원표준데이터.csv
# 소상공인시장진흥공단_상가업소정보_의료기관_201909.csv

# %%
df = pd.read_csv("소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %%
df.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  19956873     하나산부인과  NaN         S       의료       S01       병원    S01B10
# 1  20024149   타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 2  20152277  조정현신경외과의원  NaN         S       의료       S01       병원    S01B15
# 3  20350610   한귀원정신과의원  NaN         S       의료       S01       병원    S01B99
# 4  20364049  더블유스토어수지점  수지점         S       의료       S02   약국/한약방    S02A01
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0     산부인과   Q86201  ...  4127310900110810000010857  산호한양아파트
# 1    내과/외과   Q86201  ...  1168011800104670014000001      NaN
# 2     신경외과   Q86201  ...  4139013200117400001017064    한라프라자
# 3     기타병원      NaN  ...  2650010400100740001009932      NaN
# 4       약국   G47811  ...  4146510100107120002026238      NaN
#
#                  도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0   경기도 안산시 단원구 달미로 10  425764.0  15236.0  NaN  NaN  NaN  126.814295
# 1  서울특별시 강남구 언주로30길 39  135270.0   6292.0  NaN    4  NaN  127.053198
# 2    경기도 시흥시 중심상가로 178  429450.0  15066.0  NaN  NaN  NaN  126.734841
# 3    부산광역시 수영구 수영로 688  613100.0  48266.0  NaN    5  NaN  129.115438
# 4   경기도 용인시 수지구 문정로 32  448170.0  16837.0  NaN    1  NaN  127.095522
#
#           위도
# 0  37.336344
# 1  37.488742
# 2  37.344955
# 3  35.166872
# 4  37.323528
#
# [5 rows x 39 columns]

# %%
df.tail(1)
# Out:
#          상가업소번호           상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 91334  16109073  천안김안과천안역본점의원  NaN         S       의료       S01       병원
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 91334    S01B13     안과의원   Q86201  ...  4413110700102660017016314  김안과
#
#                      도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 91334  충청남도 천안시 동남구 중앙로 92  330952.0  31127.0  NaN  NaN  NaN  127.152651
#
#              위도
# 91334  36.80664
#
# [1 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   지점명        1346 non-null   object
#  3   상권업종대분류코드  91335 non-null  object
#  4   상권업종대분류명   91335 non-null  object
#  5   상권업종중분류코드  91335 non-null  object
#  6   상권업종중분류명   91335 non-null  object
#  7   상권업종소분류코드  91335 non-null  object
#  8   상권업종소분류명   91335 non-null  object
#  9   표준산업분류코드   86413 non-null  object
#  10  표준산업분류명    86413 non-null  object
#  11  시도코드       90956 non-null  float64
#  12  시도명        90956 non-null  object
#  13  시군구코드      90956 non-null  float64
#  14  시군구명       90956 non-null  object
#  15  행정동코드      91335 non-null  int64
#  16  행정동명       90956 non-null  object
#  17  법정동코드      91280 non-null  float64
#  18  법정동명       91280 non-null  object
#  19  지번코드       91335 non-null  int64
#  20  대지구분코드     91335 non-null  int64
#  21  대지구분명      91335 non-null  object
#  22  지번본번지      91335 non-null  int64
#  23  지번부번지      72079 non-null  float64
#  24  지번주소       91335 non-null  object
#  25  도로명코드      91335 non-null  int64
#  26  도로명        91335 non-null  object
#  27  건물본번지      91335 non-null  int64
#  28  건물부번지      10604 non-null  float64
#  29  건물관리번호     91335 non-null  object
#  30  건물명        46453 non-null  object
#  31  도로명주소      91335 non-null  object
#  32  구우편번호      91323 non-null  float64
#  33  신우편번호      91333 non-null  float64
#  34  동정보        7406 non-null   object
#  35  층정보        44044 non-null  object
#  36  호정보        15551 non-null  object
#  37  경도         91335 non-null  float64
#  38  위도         91335 non-null  float64
# dtypes: float64(9), int64(7), object(23)
# memory usage: 27.2+ MB

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 상가업소번호         int64
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드         float64
# 시도명           object
# 시군구코드        float64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드        float64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지          int64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호        float64
# 신우편번호        float64
# 동정보           object
# 층정보           object
# 호정보           object
# 경도           float64
# 위도           float64
# dtype: object

# %% [markdown]
# # 결측치 제거

# %%
df.isnull()
# Out:
#        상가업소번호    상호명    지점명  상권업종대분류코드  상권업종대분류명  상권업종중분류코드  상권업종중분류명  \
# 0       False  False   True      False     False      False     False
# 1       False  False   True      False     False      False     False
# 2       False  False   True      False     False      False     False
# 3       False  False   True      False     False      False     False
# 4       False  False  False      False     False      False     False
# ...       ...    ...    ...        ...       ...        ...       ...
# 91330   False  False  False      False     False      False     False
# 91331   False  False  False      False     False      False     False
# 91332   False  False   True      False     False      False     False
# 91333   False  False   True      False     False      False     False
# 91334   False  False   True      False     False      False     False
#
#        상권업종소분류코드  상권업종소분류명  표준산업분류코드  ...  건물관리번호    건물명  도로명주소  구우편번호  신우편번호  \
# 0          False     False     False  ...   False  False  False  False  False
# 1          False     False     False  ...   False   True  False  False  False
# 2          False     False     False  ...   False  False  False  False  False
# 3          False     False      True  ...   False   True  False  False  False
# 4          False     False     False  ...   False   True  False  False  False
# ...          ...       ...       ...  ...     ...    ...    ...    ...    ...
# 91330      False     False     False  ...   False   True  False  False  False
# 91331      False     False     False  ...   False  False  False  False  False
# 91332      False     False     False  ...   False  False  False  False  False
# 91333      False     False     False  ...   False   True  False  False  False
# 91334      False     False     False  ...   False  False  False  False  False
#
#         동정보    층정보   호정보     경도     위도
# 0      True   True  True  False  False
# 1      True  False  True  False  False
# 2      True   True  True  False  False
# 3      True  False  True  False  False
# 4      True  False  True  False  False
# ...     ...    ...   ...    ...    ...
# 91330  True   True  True  False  False
# 91331  True   True  True  False  False
# 91332  True  False  True  False  False
# 91333  True   True  True  False  False
# 91334  True   True  True  False  False
#
# [91335 rows x 39 columns]

# %%
null_count = df.isnull().sum()
null_count
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47291
# 호정보          75784
# 경도               0
# 위도               0
# dtype: int64

# %%
null_count.plot.barh(figsize=(5,10))
plt.show()

# %%
# reset_index() : 데이터프레임의 형태로 변환해준다.
df_null_count = null_count.reset_index()
df_null_count
# Out:
#         index      0
# 0      상가업소번호      0
# 1         상호명      0
# 2         지점명  89989
# 3   상권업종대분류코드      0
# 4    상권업종대분류명      0
# 5   상권업종중분류코드      0
# 6    상권업종중분류명      0
# 7   상권업종소분류코드      0
# 8    상권업종소분류명      0
# 9    표준산업분류코드   4922
# 10    표준산업분류명   4922
# 11       시도코드    379
# 12        시도명    379
# 13      시군구코드    379
# 14       시군구명    379
# 15      행정동코드      0
# 16       행정동명    379
# 17      법정동코드     55
# 18       법정동명     55
# 19       지번코드      0
# 20     대지구분코드      0
# 21      대지구분명      0
# 22      지번본번지      0
# 23      지번부번지  19256
# 24       지번주소      0
# 25      도로명코드      0
# 26        도로명      0
# 27      건물본번지      0
# 28      건물부번지  80731
# 29     건물관리번호      0
# 30        건물명  44882
# 31      도로명주소      0
# 32      구우편번호     12
# 33      신우편번호      2
# 34        동정보  83929
# 35        층정보  47291
# 36        호정보  75784
# 37         경도      0
# 38         위도      0

# %%
df_null_count.columns= ['컬럼명', '결측치수']
df_null_count.head()
# Out:
#          컬럼명   결측치수
# 0     상가업소번호      0
# 1        상호명      0
# 2        지점명  89989
# 3  상권업종대분류코드      0
# 4   상권업종대분류명      0

# %%
#결측치 역순으로 정렬, 상위 10개  
df_null_count_top = df_null_count.sort_values(by="결측치수", ascending=False).head(10)

# %%
#NaN = Not a Number = 결측치
df['지점명']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         수지점
#          ...
# 91330     베스트
# 91331    봄산후조
# 91332     NaN
# 91333     NaN
# 91334     NaN
# Name: 지점명, Length: 91335, dtype: object

# %%
# 리스트 형태로 담기
drop_columns = df_null_count_top['컬럼명'].tolist()
drop_columns
# Out:
# ['지점명',
#  '동정보',
#  '건물부번지',
#  '호정보',
#  '층정보',
#  '건물명',
#  '지번부번지',
#  '표준산업분류코드',
#  '표준산업분류명',
#  '시도코드']

# %%
df[drop_columns].head()
# Out:
#    지점명  동정보  건물부번지  호정보  층정보      건물명  지번부번지 표준산업분류코드         표준산업분류명  시도코드
# 0  NaN  NaN    NaN  NaN  NaN  산호한양아파트    NaN   Q86201           일반 의원  41.0
# 1  NaN  NaN    NaN  NaN    4      NaN   14.0   Q86201           일반 의원  11.0
# 2  NaN  NaN    NaN  NaN  NaN    한라프라자    1.0   Q86201           일반 의원  41.0
# 3  NaN  NaN    NaN  NaN    5      NaN    1.0      NaN             NaN  26.0
# 4  수지점  NaN    NaN  NaN    1      NaN    2.0   G47811  의약품 및 의료용품 소매업  41.0

# %%
print(df.shape)
df = df.drop(drop_columns, axis=1)
print(df.shape)
# Out:
# (91335, 39)
# (91335, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   상권업종대분류코드  91335 non-null  object
#  3   상권업종대분류명   91335 non-null  object
#  4   상권업종중분류코드  91335 non-null  object
#  5   상권업종중분류명   91335 non-null  object
#  6   상권업종소분류코드  91335 non-null  object
#  7   상권업종소분류명   91335 non-null  object
#  8   시도명        90956 non-null  object
#  9   시군구코드      90956 non-null  float64
#  10  시군구명       90956 non-null  object
#  11  행정동코드      91335 non-null  int64
#  12  행정동명       90956 non-null  object
#  13  법정동코드      91280 non-null  float64
#  14  법정동명       91280 non-null  object
#  15  지번코드       91335 non-null  int64
#  16  대지구분코드     91335 non-null  int64
#  17  대지구분명      91335 non-null  object
#  18  지번본번지      91335 non-null  int64
#  19  지번주소       91335 non-null  object
#  20  도로명코드      91335 non-null  int64
#  21  도로명        91335 non-null  object
#  22  건물본번지      91335 non-null  int64
#  23  건물관리번호     91335 non-null  object
#  24  도로명주소      91335 non-null  object
#  25  구우편번호      91323 non-null  float64
#  26  신우편번호      91333 non-null  float64
#  27  경도         91335 non-null  float64
#  28  위도         91335 non-null  float64
# dtypes: float64(6), int64(7), object(16)
# memory usage: 20.2+ MB

# %% [markdown]
# # 기초 통계값

# %%
df['위도'].mean()
# Out:
# 36.62471119236673

# %%
df['위도'].median()
# Out:
# 37.23465231770329

# %%
df['위도'].max()
# Out:
# 38.499658570559795

# %%
df['위도'].min()
# Out:
# 33.2192896688307

# %%
df['위도'].count()
# Out:
# 91335

# %%
df['위도'].describe()
# Out:
# count    91335.000000
# mean        36.624711
# std          1.041361
# min         33.219290
# 25%         35.811830
# 50%         37.234652
# 75%         37.507463
# max         38.499659
# Name: 위도, dtype: float64

# %%
#2개 이상의 컬럼을 가져올 때는 list형태로 담아줘야 한다
df[['위도', '경도']].describe()
# Out:
#                  위도            경도
# count  91335.000000  91335.000000
# mean      36.624711    127.487524
# std        1.041361      0.842877
# min       33.219290    124.717632
# 25%       35.811830    126.914297
# 50%       37.234652    127.084550
# 75%       37.507463    128.108919
# max       38.499659    130.909912

# %%
df.describe(include="object")
# Out:
#           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명    시도명  \
# count   91335     91335    91335     91335    91335     91335    91335  90956
# unique  56910         1        1         5        5        34       34     17
# top        리원         S       의료       S01       병원    S02A01       약국    경기도
# freq      152     91335    91335     60774    60774     18964    18964  21374
#
#          시군구명   행정동명   법정동명  대지구분명                  지번주소             도로명  \
# count   90956  90956  91280  91335                 91335           91335
# unique    228   2791   2822      2                 53118           16610
# top        서구    중앙동     중동     대지  서울특별시 동대문구 제기동 965-1  서울특별시 강남구 강남대로
# freq     3165   1856    874  91213                   198             326
#
#                            건물관리번호                  도로명주소
# count                       91335                  91335
# unique                      54142                  54031
# top     1123010300109650001031604  서울특별시 동대문구 약령중앙로8길 10
# freq                          198                    198

# %%
df['상권업종대분류명'].unique()
# Out:
# array(['의료'], dtype=object)

# %%
df['상권업종대분류명'].nunique()
# Out:
# 1

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['병원', '약국/한약방', '수의업', '유사의료업', '의료관련서비스업'], dtype=object)

# %%
df['상권업종중분류명'].nunique()
# Out:
# 5

# %%
df['상권업종소분류명'].unique()
# Out:
# array(['산부인과', '내과/외과', '신경외과', '기타병원', '약국', '동물병원', '한약방', '탕제원',
#        '정형/성형외과', '소아과', '이비인후과의원', '노인/치매병원', '언어치료', '수의업-종합', '한의원',
#        '치과의원', '침구원', '일반병원', '안과의원', '조산원', '한방병원', '종합병원', '유사의료업기타',
#        '응급구조대', '혈액원', '치과병원', '척추교정치료', '피부과', '비뇨기과', '치과기공소', '산후조리원',
#        '접골원', '수의업-기타', '제대혈'], dtype=object)

# %%
df['상권업종소분류명'].nunique()
# Out:
# 34

# %%
city = df['시도명'].value_counts()
city
# Out:
# 경기도        21374
# 서울특별시      18943
# 부산광역시       6473
# 경상남도        4973
# 인천광역시       4722
# 대구광역시       4597
# 경상북도        4141
# 전라북도        3894
# 충청남도        3578
# 전라남도        3224
# 광주광역시       3214
# 대전광역시       3067
# 충청북도        2677
# 강원도         2634
# 울산광역시       1997
# 제주특별자치도     1095
# 세종특별자치시      353
# Name: 시도명, dtype: int64

# %%
# normalize=True : 전체에서 차지하는 비율 파악 가능
city_normalize = df['시도명'].value_counts(normalize=True)
city_normalize
# Out:
# 경기도        0.234993
# 서울특별시      0.208266
# 부산광역시      0.071166
# 경상남도       0.054675
# 인천광역시      0.051915
# 대구광역시      0.050541
# 경상북도       0.045528
# 전라북도       0.042812
# 충청남도       0.039338
# 전라남도       0.035446
# 광주광역시      0.035336
# 대전광역시      0.033720
# 충청북도       0.029432
# 강원도        0.028959
# 울산광역시      0.021956
# 제주특별자치도    0.012039
# 세종특별자치시    0.003881
# Name: 시도명, dtype: float64

# %%
city.plot.barh()

# %%
city_normalize.plot.barh()

# %%
sns.countplot(data=df, y="시도명")

# %%
sns.countplot(data=df, y="상권업종중분류명")

# %%
c = df['상권업종중분류명'].value_counts()
c
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
n = df['상권업종중분류명'].value_counts(normalize=True)
n
# Out:
# 병원          0.665397
# 약국/한약방      0.229080
# 수의업         0.058280
# 유사의료업       0.041320
# 의료관련서비스업    0.005923
# Name: 상권업종중분류명, dtype: float64

# %%
c.plot.bar(rot=0)

# %%
n.plot.pie()

# %%
d = df['상권업종소분류명'].value_counts()
d
# Out:
# 약국         18964
# 치과의원       13731
# 한의원        13211
# 내과/외과      11374
# 기타병원        4922
# 일반병원        3385
# 동물병원        3098
# 정형/성형외과     2562
# 소아과         2472
# 수의업-종합      2216
# 치과기공소       1724
# 이비인후과의원     1486
# 한약방         1442
# 피부과         1273
# 산부인과        1116
# 노인/치매병원     1055
# 안과의원        1042
# 비뇨기과         809
# 종합병원         762
# 치과병원         756
# 언어치료         664
# 유사의료업기타      629
# 탕제원          517
# 산후조리원        511
# 신경외과         421
# 한방병원         397
# 척추교정치료       338
# 침구원          154
# 혈액원          130
# 응급구조대        125
# 조산원           30
# 수의업-기타         9
# 접골원            9
# 제대혈            1
# Name: 상권업종소분류명, dtype: int64

# %%
d.plot.barh(figsize=(7,8), grid=True)

# %% [markdown]
# # 데이터 색인하기

# %%
df_medical = df[df['상권업종중분류명'] == '약국/한약방'].copy()
df_medical
# Out:
#          상가업소번호        상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 4      20364049  더블유스토어수지점         S       의료       S02   약국/한약방    S02A01
# 6      20733252      춘산한약방         S       의료       S02   약국/한약방    S02A02
# 7      20582210      부부탕제원         S       의료       S02   약국/한약방    S02A03
# 10     21057519       민생약국         S       의료       S02   약국/한약방    S02A01
# 13     21217689     제중당한약방         S       의료       S02   약국/한약방    S02A02
# ...         ...        ...       ...      ...       ...      ...       ...
# 91312  16131397      큰나무약국         S       의료       S02   약국/한약방    S02A01
# 91321  16130841       복음약국         S       의료       S02   약국/한약방    S02A01
# 91322  16091491  설연화한복감성약방         S       의료       S02   약국/한약방    S02A01
# 91324  16109731      위례수약국         S       의료       S02   약국/한약방    S02A01
# 91330  16196725      온누리약국         S       의료       S02   약국/한약방    S02A01
#
#       상권업종소분류명    시도명    시군구코드  ...                     지번주소         도로명코드  \
# 4           약국    경기도  41465.0  ...   경기도 용인시 수지구 풍덕천동 712-2  414653205024
# 6          한약방    강원도  42110.0  ...         강원도 춘천시 중앙로2가 99  421104454113
# 7          탕제원   충청북도  43111.0  ...  충청북도 청주시 상당구 금천동 187-17  431114508623
# 10          약국   경상남도  48890.0  ...    경상남도 합천군 용주면 월평리 78-2  488904844473
# 13         한약방   전라남도  46830.0  ...     전라남도 영암군 도포면 덕화리 296  468304685396
# ...        ...    ...      ...  ...                      ...           ...
# 91312       약국    경기도  41281.0  ...   경기도 고양시 덕양구 성사동 700-11  412812192001
# 91321       약국  대구광역시  27290.0  ...         대구광역시 달서구 본동 276  272904241030
# 91322       약국  서울특별시  11260.0  ...       서울특별시 중랑구 묵동 174-1  112603005050
# 91324       약국    경기도  41131.0  ...    경기도 성남시 수정구 창곡동 559-4  411313350738
# 91330       약국  대전광역시  30170.0  ...        대전광역시 서구 둔산동 1507  301703166026
#
#                           도로명  건물본번지                     건물관리번호  \
# 4             경기도 용인시 수지구 문정로     32  4146510100107120002026238
# 6                 강원도 춘천시 낙원길     50  4211010500101000000023668
# 7      충청북도 청주시 상당구 중고개로337번길    134  4311112000101870017042942
# 10           경상남도 합천군 용주면 월평길    149  4889046030200780002048274
# 13           전라남도 영암군 도포면 인덕길     75  4683035023102960000000001
# ...                       ...    ...                        ...
# 91312        경기도 고양시 덕양구 고양대로   1361  4128110600107000011013834
# 91321        대구광역시 달서구 구마로36길     33  2729012400102760000029818
# 91322           서울특별시 중랑구 공릉로     28  1126010400101740001009985
# 91324       경기도 성남시 수정구 위례서일로     18  4113110800101810002000002
# 91330            대전광역시 서구 문예로     67  3017011200115070000021096
#
#                             도로명주소     구우편번호    신우편번호          경도         위도
# 4              경기도 용인시 수지구 문정로 32  448170.0  16837.0  127.095522  37.323528
# 6                  강원도 춘천시 낙원길 50  200042.0  24273.0  127.726905  37.880504
# 7      충청북도 청주시 상당구 중고개로337번길 134  360802.0  28726.0  127.499206  36.625355
# 10        경상남도 합천군 용주면 월평길 149-35  678912.0  50212.0  128.118615  35.575962
# 13         전라남도 영암군 도포면 인덕길 75-10  526832.0  58429.0  126.630348  34.834080
# ...                           ...       ...      ...         ...        ...
# 91312       경기도 고양시 덕양구 고양대로 1361  412807.0  10464.0  126.835684  37.655048
# 91321         대구광역시 달서구 구마로36길 33  704752.0  42735.0  128.547352  35.836250
# 91322            서울특별시 중랑구 공릉로 28  131848.0   2034.0  127.078082  37.613194
# 91324        경기도 성남시 수정구 위례서일로 18  461210.0  13647.0  127.137870  37.465260
# 91330             대전광역시 서구 문예로 67  302831.0  35240.0  127.389865  36.352728
#
# [20923 rows x 29 columns]

# %%
df.loc[df['상권업종대분류명'] =='의료','상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
m = df['상권업종대분류명'] =='의료'
df.loc[m, '상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
df_medi = df[df['상권업종중분류명'] == '유사의료업']
df_medi
# Out:
#          상가업소번호         상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 22     21013731    세종언어치료센터         S       의료       S03    유사의료업    S03B07
# 40     20933900     고려수지침학회         S       의료       S03    유사의료업    S03B03
# 97     21717820         청명원         S       의료       S03    유사의료업    S03B09
# 102    21865854    응급환자이송센터         S       의료       S03    유사의료업    S03B01
# 108    21914637  태화아동발달지원센터         S       의료       S03    유사의료업    S03B07
# ...         ...         ...       ...      ...       ...      ...       ...
# 91300  16131218     으뜸치과기공소         S       의료       S03    유사의료업    S03B06
# 91310  16199325     보령치과기공소         S       의료       S03    유사의료업    S03B06
# 91311  16199088       점프셈교실         S       의료       S03    유사의료업    S03B09
# 91319  16108560  씨앤디자인치과기공소         S       의료       S03    유사의료업    S03B06
# 91327  16190388       오피스알파         S       의료       S03    유사의료업    S03B06
#
#       상권업종소분류명    시도명    시군구코드  ...                     지번주소         도로명코드  \
# 22        언어치료  부산광역시  26410.0  ...       부산광역시 금정구 구서동 84-1  264102000010
# 40         침구원   경상남도  48123.0  ...     경상남도 창원시 성산구 상남동 5-2  481234784088
# 97     유사의료업기타   충청북도  43760.0  ...     충청북도 괴산군 청안면 금신리 241  437604538132
# 102      응급구조대  대전광역시  30140.0  ...     대전광역시 중구 대사동 248-237  301404295026
# 108       언어치료  대전광역시  30140.0  ...          대전광역시 중구 문화동 27  301404295402
# ...        ...    ...      ...  ...                      ...           ...
# 91300    치과기공소   경상남도  48170.0  ...       경상남도 진주시 수정동 39-11  481704797625
# 91310    치과기공소  서울특별시  11290.0  ...  서울특별시 성북구 동소문동4가 103-11  112903107003
# 91311  유사의료업기타   경상북도  47130.0  ...         경상북도 경주시 황성동 446  471304715895
# 91319    치과기공소  서울특별시  11545.0  ...      서울특별시 금천구 가산동 60-25  115453116013
# 91327    치과기공소    경기도  41173.0  ...   경기도 안양시 동안구 호계동 970-24  411734349013
#
#                          도로명  건물본번지                     건물관리번호  \
# 22            부산광역시 금정구 중앙대로   1817  2641010700100840001017686
# 40      경상남도 창원시 성산구 마디미로4번길      9  4812312700100050002026799
# 97        충청북도 괴산군 청안면 금신로1길     93  4376037022102410000007293
# 102        대전광역시 중구 계룡로921번길     40  3014011000102480237013097
# 108       대전광역시 중구 보문산로333번길     29  3014011600100270000008172
# ...                      ...    ...                        ...
# 91300       경상남도 진주시 향교로18번길      8  4817011600100390011004490
# 91310         서울특별시 성북구 동소문로     47  1129010700101030014050661
# 91311      경상북도 경주시 용담로104번길     16  4713012400104460000024894
# 91319          서울특별시 금천구 벚꽃로    234  1154510100100600025000001
# 91327  경기도 안양시 동안구 경수대로507번길     28  4117310400109700024005182
#
#                           도로명주소     구우편번호    신우편번호          경도         위도
# 22       부산광역시 금정구 중앙대로 1817-11  609310.0  46273.0  129.091662  35.246528
# 40       경상남도 창원시 성산구 마디미로4번길 9  642832.0  51495.0  128.684678  35.224113
# 97        충청북도 괴산군 청안면 금신로1길 93  367831.0  28050.0  127.635740  36.768935
# 102        대전광역시 중구 계룡로921번길 40  301846.0  34946.0  127.417693  36.321801
# 108       대전광역시 중구 보문산로333번길 29  301130.0  35020.0  127.412725  36.312953
# ...                         ...       ...      ...         ...        ...
# 91300        경상남도 진주시 향교로18번길 8  660180.0  52753.0  128.084600  35.197029
# 91310      서울특별시 성북구 동소문로 47-15  136821.0   2832.0  127.010602  37.591455
# 91311      경상북도 경주시 용담로104번길 16  780954.0  38084.0  129.211755  35.865600
# 91319         서울특별시 금천구 벚꽃로 234  153798.0   8513.0  126.886122  37.475986
# 91327  경기도 안양시 동안구 경수대로507번길 28  431849.0  14120.0  126.956365  37.367779
#
# [3774 rows x 29 columns]

# %%
df['상호명'].value_counts().head()
# Out:
# 리원       152
# 온누리약국    149
# 경희한의원    141
# 우리약국     119
# 중앙약국     111
# Name: 상호명, dtype: int64

# %%
df_medi["상호명"].value_counts().head(10)
# Out:
# 리원          32
# 고려수지침       22
# 대한적십자사      17
# 헌혈의집        12
# 수치과기공소      10
# 고려수지침학회     10
# 제일치과기공소      9
# 아트치과기공소      8
# 미소치과기공소      8
# 어울림치과기공소     8
# Name: 상호명, dtype: int64

# %%
df_seoul_drug = df[(df['상권업종소분류명'] =='약국') & (df['시도명'] == '서울특별시')]
print(df_seoul_drug.shape)
df_seoul_drug.head()
# Out:
# (3579, 29)
#        상가업소번호      상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 33   20816709    이즈타워약         S       의료       S02   약국/한약방    S02A01
# 51   20855710     진흥약국         S       의료       S02   약국/한약방    S02A01
# 130  21589838    신세계약국         S       의료       S02   약국/한약방    S02A01
# 136  22388303  메디팜한솔약국         S       의료       S02   약국/한약방    S02A01
# 141  22412563      명약국         S       의료       S02   약국/한약방    S02A01
#
#     상권업종소분류명    시도명    시군구코드  ...                    지번주소         도로명코드  \
# 33        약국  서울특별시  11680.0  ...       서울특별시 강남구 역삼동 821  116803122010
# 51        약국  서울특별시  11740.0  ...       서울특별시 강동구 둔촌동 630  117403124002
# 130       약국  서울특별시  11260.0  ...       서울특별시 중랑구 신내동 646  112603106007
# 136       약국  서울특별시  11200.0  ...       서울특별시 성동구 행당동 346  112003103006
# 141       약국  서울특별시  11230.0  ...  서울특별시 동대문구 휘경동 286-121  112304115120
#
#                     도로명  건물본번지                     건물관리번호  \
# 33       서울특별시 강남구 테헤란로    101  1168010100108210001000001
# 51        서울특별시 강동구 명일로    172  1174010600106090000000001
# 130       서울특별시 중랑구 신내로    211  1126010600106460000000300
# 136       서울특별시 성동구 행당로     82  1120010700103460012016935
# 141  서울특별시 동대문구 망우로18나길      3  1123010900102860121007257
#
#                     도로명주소     구우편번호   신우편번호          경도         위도
# 33     서울특별시 강남구 테헤란로 101  135080.0  6134.0  127.028023  37.498656
# 51      서울특별시 강동구 명일로 172  134767.0  5360.0  127.145055  37.534135
# 130     서울특별시 중랑구 신내로 211  131130.0  2024.0  127.092597  37.616424
# 136      서울특별시 성동구 행당로 82  133777.0  4717.0  127.027513  37.556238
# 141  서울특별시 동대문구 망우로18나길 3  130090.0  2498.0  127.060556  37.587349
#
# [5 rows x 29 columns]

# %%
e = df_seoul_drug["시군구명"].value_counts()
e.head()
# Out:
# 강남구     374
# 동대문구    261
# 광진구     212
# 서초구     191
# 송파구     188
# Name: 시군구명, dtype: int64

# %%
f = df_seoul_drug["시군구명"].value_counts(normalize=True)
f.head()
# Out:
# 강남구     0.104498
# 동대문구    0.072925
# 광진구     0.059234
# 서초구     0.053367
# 송파구     0.052529
# Name: 시군구명, dtype: float64

# %%
e.plot.bar(rot=60, figsize=(10,7))

# %%
df_seoul_hospital = df[(df["상권업종소분류명"] == '종합병원') & (df['시도명'] == '서울특별시')].copy()

# %%
df_seoul_hospital['시군구명'].value_counts()
# Out:
# 강남구     15
# 영등포구     8
# 광진구      6
# 서초구      6
# 강동구      5
# 중구       5
# 송파구      5
# 강북구      4
# 서대문구     4
# 도봉구      4
# 양천구      4
# 성북구      3
# 관악구      2
# 성동구      2
# 동대문구     2
# 중랑구      2
# 종로구      2
# 구로구      2
# 노원구      2
# 금천구      2
# 강서구      2
# 은평구      1
# 동작구      1
# 용산구      1
# 마포구      1
# Name: 시군구명, dtype: int64

# %%
df_seoul_hospital['상호명'].unique()
# Out:
# array(['대진의료재단', '홍익병원별관', 'SNUH', '평화드림여의도성모병원의료기매장', '한양', '백산의료재단친구병원',
#        '서울보훈병원', '서울성모병원장례식장꽃배달', '서울대학교병원', '알콜중독및정신질환상담소',
#        '강남성모병원장례식장꽃배달', '제일병원', '이랜드클리닉', '사랑나눔의료재단', '우울증센터', '성심의료재단',
#        '다나의료재단', '서울아산병원신관', '원자력병원장례식장', '국민의원', '고려대학교구로병원', '학교법인일송학원',
#        '삼성의료원장례식장', '희명스포츠의학센터인공신장실', '연세대학교의과대학강남세브란스', '국립정신병원',
#        '코아클리닉', '수서제일의원', '사랑의의원', '한국전력공사부속한일병원', '신촌연세병원', '창동제일의원',
#        '영동세브란스병원', '제일성심의원', '삼성의료재단강북삼성태', '서울시립보라매병원', '서울이의원',
#        '서울대학교병원비상계획외래', '평화드림서울성모병원의료', '홍익병원', '사랑나눔의료재단서', '독일의원',
#        '서울연합의원', '우신향병원', '동부제일병원', '아산재단금강병원', '명곡안연구소', '아산재단서울중앙병원',
#        '메디힐특수여객', '삼성생명공익재단삼성서', '성광의료재단차병원', '한국건강관리협회서울특',
#        '정해복지부설한신메디피아', '성베드로병원', '성애의료재단', '실로암의원', 'Y&T성모마취과', '광진성모의원',
#        '서울현대의원', '이노신경과의원', '송정훼밀리의원', '서울중앙의원', '영남의료재단', '인제대학교서울백병원',
#        '한국필의료재단', '세브란스의원', '가톨릭대학교성바오로병원장례식장', '서울연세의원', '사랑의병원',
#        '성삼의료재단미즈메디병원', '씨엠충무병원', '성신의원', '원진재단부설녹색병원', '송파제일의원',
#        '카톨릭성모의원', '한양성심의원', '관악성모의원', '강남센트럴병원', '우이한솔의원', '우리들병원',
#        '서울성모병원어린이집', '건국대학교병원', '서울적십자병원', '북부성모의원', '한림대학교부속한강성심병원장례식장',
#        '서울성모병원응급의료센터', '라마르의원', '가톨릭대학교여의도성모병원', '씨엠병원'], dtype=object)

# %%
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains("꽃배달")]
# Out:
#         상가업소번호            상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 2803  20895655  서울성모병원장례식장꽃배달         S       의료       S01       병원    S01B01
# 4644  22020310  강남성모병원장례식장꽃배달         S       의료       S01       병원    S01B01
#
#      상권업종소분류명    시도명    시군구코드  ...                 지번주소         도로명코드  \
# 2803     종합병원  서울특별시  11650.0  ...    서울특별시 서초구 반포동 551  116504163330
# 4644     종합병원  서울특별시  11650.0  ...  서울특별시 서초구 반포동 547-6  116504163242
#
#                     도로명  건물본번지                     건물관리번호  \
# 2803  서울특별시 서초구 사평대로28길     55  1165010700105510000017194
# 4644  서울특별시 서초구 반포대로39길     56  1165010700105470006016762
#
#                         도로명주소     구우편번호   신우편번호          경도         위도
# 2803     서울특별시 서초구 사평대로28길 55  137040.0  6578.0  127.000682  37.498257
# 4644  서울특별시 서초구 반포대로39길 56-24  137040.0  6578.0  127.001756  37.499095
#
# [2 rows x 29 columns]

# %%
drop_row = df_seoul_hospital[df_seoul_hospital['상호명'].str.contains("꽃배달|의료기|장례식장|상담소|어린이집")].index
drop_row
# Out:
# Int64Index([1917, 2803, 4431, 4644, 7938, 10283, 47008, 60645, 70177], dtype='int64')

# %%
drop_row = drop_row.tolist()

# %%
drop_row
# Out:
# [1917, 2803, 4431, 4644, 7938, 10283, 47008, 60645, 70177]

# %%
drop_row2 = df_seoul_hospital[df_seoul_hospital["상호명"].str.endswith("의원")].index
drop_row2 = drop_row2.tolist()
drop_row2
# Out:
# [8479,
#  12854,
#  13715,
#  14966,
#  16091,
#  18047,
#  20200,
#  20415,
#  30706,
#  32889,
#  34459,
#  34720,
#  35696,
#  37251,
#  45120,
#  49626,
#  51575,
#  55133,
#  56320,
#  56404,
#  56688,
#  57551,
#  62113,
#  76508]

# %%
drop_row = drop_row + drop_row2

# %%
len(drop_row)
# Out:
# 33

# %%
print(df_seoul_hospital.shape)
df_seoul_hospital = df_seoul_hospital.drop(drop_row, axis=0)
print(df_seoul_hospital.shape)
# Out:
# (91, 29)
# (58, 29)

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df_seoul_hospital, x='시군구명',
             order=df_seoul_hospital['시군구명'].value_counts().index)
plt.show()

# %% [markdown]
# # 특정 지역만 보기

# %%
df_seoul = df[df['시도명'] == '서울특별시'].copy()
df_seoul.shape
# Out:
# (18943, 29)

# %%
df_seoul['시군구명'].value_counts().plot.bar(figsize=(10,4), rot=60)

# %%
plt.figure(figsize=(18,4))
sns.countplot(data=df_seoul, x='시군구명')

# %%
# 수치형 데이터 시각화 = scatter
df_seoul[["경도", "위도", "시군구명"]].plot.scatter(x="경도", y="위도", figsize=(8,7), grid=True)

# %%
sns.scatterplot(data=df_seoul, x='경도', y='위도', hue="상권업종중분류명")

# %%
plt.figure(figsize=(16,12))
sns.scatterplot(data=df, x='경도', y='위도', hue="시도명")

# %% [markdown]
# # Folium 사용하기

# %%
conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul_hospital["위도"].mean()
# Out:
# 37.52972276355594

# %%
df_seoul_hospital["경도"].mean()
# Out:
# 126.9963589356625

# %%
map = folium.Map(location=[df_seoul_hospital["위도"].mean(), df_seoul_hospital["경도"].mean()],
          zoom_start=12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # For 문

# %%
for n in df_seoul_hospital.index:
    print(df_seoul_hospital.loc[n])
# Out:
# 상가업소번호                        25155642
# 상호명                             대진의료재단
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11215
# 시군구명                               광진구
# 행정동코드                       1121577000
# 행정동명                              중곡4동
# 법정동코드                      1.12151e+09
# 법정동명                               중곡동
# 지번코드               1121510100200580025
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               58
# 지번주소               서울특별시 광진구 중곡동 58-25
# 도로명코드                     112153104006
# 도로명                     서울특별시 광진구 긴고랑로
# 건물본번지                              119
# 건물관리번호       1121510100100580025000733
# 도로명주소               서울특별시 광진구 긴고랑로 119
# 구우편번호                           143220
# 신우편번호                             4944
# 경도                             127.088
# 위도                              37.559
# Name: 305, dtype: object
# 상가업소번호                        20471487
# 상호명                             홍익병원별관
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11470
# 시군구명                               양천구
# 행정동코드                       1147065000
# 행정동명                              신정4동
# 법정동코드                      1.14701e+09
# 법정동명                               신정동
# 지번코드               1147010100208970013
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              897
# 지번주소              서울특별시 양천구 신정동 897-13
# 도로명코드                     114702005008
# 도로명                     서울특별시 양천구 국회대로
# 건물본번지                              250
# 건물관리번호       1147010100108970013001044
# 도로명주소               서울특별시 양천구 국회대로 250
# 구우편번호                           158070
# 신우편번호                             7937
# 경도                             126.863
# 위도                             37.5292
# Name: 353, dtype: object
# 상가업소번호                        20737057
# 상호명                               SNUH
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168064000
# 행정동명                              역삼1동
# 법정동코드                      1.16801e+09
# 법정동명                               역삼동
# 지번코드               1168010100207360055
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              736
# 지번주소              서울특별시 강남구 역삼동 736-55
# 도로명코드                     116804166727
# 도로명                  서울특별시 강남구 테헤란로26길
# 건물본번지                               10
# 건물관리번호       1168010100107360055027688
# 도로명주소             서울특별시 강남구 테헤란로26길 10
# 구우편번호                           135080
# 신우편번호                             6236
# 경도                             127.036
# 위도                             37.4996
# Name: 385, dtype: object
# 상가업소번호                        20024045
# 상호명                                 한양
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11200
# 시군구명                               성동구
# 행정동코드                       1120055000
# 행정동명                               사근동
# 법정동코드                      1.12001e+09
# 법정동명                               행당동
# 지번코드               1120010700200150001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               15
# 지번주소                서울특별시 성동구 행당동 15-1
# 도로명코드                     112003103002
# 도로명                      서울특별시 성동구 마조로
# 건물본번지                               22
# 건물관리번호       1120010700100150001019623
# 도로명주소               서울특별시 성동구 마조로 22-2
# 구우편번호                           133070
# 신우편번호                             4763
# 경도                             127.041
# 위도                             37.5595
# Name: 2461, dtype: object
# 상가업소번호                        20890249
# 상호명                         백산의료재단친구병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11740
# 시군구명                               강동구
# 행정동코드                       1174061000
# 행정동명                              천호2동
# 법정동코드                      1.17401e+09
# 법정동명                               천호동
# 지번코드               1174010900203570000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              357
# 지번주소                 서울특별시 강동구 천호동 357
# 도로명코드                     117403123023
# 도로명                     서울특별시 강동구 올림픽로
# 건물본번지                              684
# 건물관리번호       1174010900103570000009066
# 도로명주소               서울특별시 강동구 올림픽로 684
# 구우편번호                           134750
# 신우편번호                             5327
# 경도                             127.125
# 위도                             37.5423
# Name: 2687, dtype: object
# 상가업소번호                        20867576
# 상호명                             서울보훈병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11740
# 시군구명                               강동구
# 행정동코드                       1174070000
# 행정동명                              둔촌2동
# 법정동코드                      1.17401e+09
# 법정동명                               둔촌동
# 지번코드               1174010600200060002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                                6
# 지번주소                 서울특별시 강동구 둔촌동 6-2
# 도로명코드                     117404172320
# 도로명                  서울특별시 강동구 진황도로61길
# 건물본번지                               53
# 건물관리번호       1174010600100060002000302
# 도로명주소             서울특별시 강동구 진황도로61길 53
# 구우편번호                           134791
# 신우편번호                             5368
# 경도                             127.148
# 위도                             37.5285
# Name: 2801, dtype: object
# 상가업소번호                        21914819
# 상호명                            서울대학교병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168064000
# 행정동명                              역삼1동
# 법정동코드                      1.16801e+09
# 법정동명                               역삼동
# 지번코드               1168010100207370000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              737
# 지번주소                 서울특별시 강남구 역삼동 737
# 도로명코드                     116803122010
# 도로명                     서울특별시 강남구 테헤란로
# 건물본번지                              152
# 건물관리번호       1168010100107370000023659
# 도로명주소               서울특별시 강남구 테헤란로 152
# 구우편번호                           135984
# 신우편번호                             6236
# 경도                             127.036
# 위도                                37.5
# Name: 4285, dtype: object
# 상가업소번호                        22256379
# 상호명                               제일병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11140
# 시군구명                                중구
# 행정동코드                       1114057000
# 행정동명                                필동
# 법정동코드                      1.11401e+09
# 법정동명                               묵정동
# 지번코드               1114013600200010019
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                                1
# 지번주소                 서울특별시 중구 묵정동 1-19
# 도로명코드                     111404103183
# 도로명                     서울특별시 중구 서애로1길
# 건물본번지                               17
# 건물관리번호       1114013600100010002018718
# 도로명주소                서울특별시 중구 서애로1길 17
# 구우편번호                           100380
# 신우편번호                             4619
# 경도                                 127
# 위도                             37.5617
# Name: 4856, dtype: object
# 상가업소번호                        22439143
# 상호명                             이랜드클리닉
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11545
# 시군구명                               금천구
# 행정동코드                       1154551000
# 행정동명                               가산동
# 법정동코드                      1.15451e+09
# 법정동명                               가산동
# 지번코드               1154510100204590011
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              459
# 지번주소              서울특별시 금천구 가산동 459-11
# 도로명코드                     115453117001
# 도로명                  서울특별시 금천구 가산디지털1로
# 건물본번지                              186
# 건물관리번호       1154510100104590011000001
# 도로명주소            서울특별시 금천구 가산디지털1로 186
# 구우편번호                           153792
# 신우편번호                             8502
# 경도                             126.882
# 위도                             37.4819
# Name: 5005, dtype: object
# 상가업소번호                        22470053
# 상호명                           사랑나눔의료재단
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11410
# 시군구명                              서대문구
# 행정동코드                       1141056500
# 행정동명                               충현동
# 법정동코드                      1.14101e+09
# 법정동명                             충정로3가
# 지번코드               1141010200204640000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              464
# 지번주소              서울특별시 서대문구 충정로3가 464
# 도로명코드                     114103005010
# 도로명                    서울특별시 서대문구 서소문로
# 건물본번지                               21
# 건물관리번호       1141010200104640000030855
# 도로명주소               서울특별시 서대문구 서소문로 21
# 구우편번호                           120723
# 신우편번호                             3742
# 경도                             126.964
# 위도                             37.5599
# Name: 5089, dtype: object
# 상가업소번호                        23913570
# 상호명                              우울증센터
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11290
# 시군구명                               성북구
# 행정동코드                       1129060000
# 행정동명                               안암동
# 법정동코드                      1.12901e+09
# 법정동명                             안암동5가
# 지번코드               1129012500200010002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                                1
# 지번주소               서울특별시 성북구 안암동5가 1-2
# 도로명코드                     112903005035
# 도로명                      서울특별시 성북구 안암로
# 건물본번지                              145
# 건물관리번호       1129012500100010002039525
# 도로명주소                서울특별시 성북구 안암로 145
# 구우편번호                           136701
# 신우편번호                             2841
# 경도                             127.032
# 위도                             37.5885
# Name: 5759, dtype: object
# 상가업소번호                        24720669
# 상호명                             성심의료재단
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156053500
# 행정동명                              영등포동
# 법정동코드                      1.15601e+09
# 법정동명                            영등포동7가
# 지번코드               1156010800200940017
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               94
# 지번주소           서울특별시 영등포구 영등포동7가 94-17
# 도로명코드                     115603118010
# 도로명                   서울특별시 영등포구 버드나루로
# 건물본번지                               55
# 건물관리번호       1156010800100940102032486
# 도로명주소              서울특별시 영등포구 버드나루로 55
# 구우편번호                           150037
# 신우편번호                             7247
# 경도                              126.91
# 위도                             37.5234
# Name: 5824, dtype: object
# 상가업소번호                        24422372
# 상호명                             다나의료재단
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11530
# 시군구명                               구로구
# 행정동코드                       1153074000
# 행정동명                              개봉1동
# 법정동코드                      1.15301e+09
# 법정동명                               개봉동
# 지번코드               1153010700203530002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              353
# 지번주소               서울특별시 구로구 개봉동 353-2
# 도로명코드                     115303116001
# 도로명                      서울특별시 구로구 개봉로
# 건물본번지                              126
# 건물관리번호       1153010700101610005006919
# 도로명주소                서울특별시 구로구 개봉로 126
# 구우편번호                           152090
# 신우편번호                             8277
# 경도                             126.857
# 위도                             37.4967
# Name: 5867, dtype: object
# 상가업소번호                         5920343
# 상호명                           서울아산병원신관
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11710
# 시군구명                               송파구
# 행정동코드                       1171052000
# 행정동명                              풍납2동
# 법정동코드                      1.17101e+09
# 법정동명                               풍납동
# 지번코드               1171010300203880001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              388
# 지번주소               서울특별시 송파구 풍납동 388-1
# 도로명코드                     117104169435
# 도로명                  서울특별시 송파구 올림픽로43길
# 건물본번지                               88
# 건물관리번호       1171010300103880001024947
# 도로명주소             서울특별시 송파구 올림픽로43길 88
# 구우편번호                           138736
# 신우편번호                             5505
# 경도                             127.109
# 위도                             37.5252
# Name: 6978, dtype: object
# 상가업소번호                        21736553
# 상호명                          고려대학교구로병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11530
# 시군구명                               구로구
# 행정동코드                       1153053000
# 행정동명                              구로2동
# 법정동코드                      1.15301e+09
# 법정동명                               구로동
# 지번코드               1153010200200800000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               80
# 지번주소                  서울특별시 구로구 구로동 80
# 도로명코드                     115303005070
# 도로명                     서울특별시 구로구 구로동로
# 건물본번지                              148
# 건물관리번호       1153010200100800000024727
# 도로명주소               서울특별시 구로구 구로동로 148
# 구우편번호                           152703
# 신우편번호                             8308
# 경도                             126.885
# 위도                             37.4912
# Name: 8706, dtype: object
# 상가업소번호                        24828735
# 상호명                           학교법인일송학원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156053500
# 행정동명                              영등포동
# 법정동코드                      1.15601e+09
# 법정동명                            영등포동7가
# 지번코드               1156010800200940017
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               94
# 지번주소           서울특별시 영등포구 영등포동7가 94-17
# 도로명코드                     115603118010
# 도로명                   서울특별시 영등포구 버드나루로
# 건물본번지                               55
# 건물관리번호       1156010800100940102032486
# 도로명주소              서울특별시 영등포구 버드나루로 55
# 구우편번호                           150037
# 신우편번호                             7247
# 경도                              126.91
# 위도                             37.5234
# Name: 9529, dtype: object
# 상가업소번호                        25370236
# 상호명                     희명스포츠의학센터인공신장실
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11545
# 시군구명                               금천구
# 행정동코드                       1154567000
# 행정동명                              시흥1동
# 법정동코드                      1.15451e+09
# 법정동명                               시흥동
# 지번코드               1154510300208830005
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              883
# 지번주소               서울특별시 금천구 시흥동 883-5
# 도로명코드                     115452005010
# 도로명                     서울특별시 금천구 시흥대로
# 건물본번지                              230
# 건물관리번호       1154510300108830005017218
# 도로명주소               서울특별시 금천구 시흥대로 230
# 구우편번호                           153030
# 신우편번호                             8628
# 경도                             126.901
# 위도                             37.4544
# Name: 10937, dtype: object
# 상가업소번호                        24648465
# 상호명                    연세대학교의과대학강남세브란스
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168065500
# 행정동명                              도곡1동
# 법정동코드                      1.16801e+09
# 법정동명                               도곡동
# 지번코드               1168011800201460092
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              146
# 지번주소              서울특별시 강남구 도곡동 146-92
# 도로명코드                     116803005086
# 도로명                      서울특별시 강남구 언주로
# 건물본번지                              211
# 건물관리번호       1168011800101460092026388
# 도로명주소                서울특별시 강남구 언주로 211
# 구우편번호                           135720
# 신우편번호                             6273
# 경도                             127.046
# 위도                             37.4928
# Name: 10958, dtype: object
# 상가업소번호                        23073664
# 상호명                             국립정신병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11215
# 시군구명                               광진구
# 행정동코드                       1121576000
# 행정동명                              중곡3동
# 법정동코드                      1.12151e+09
# 법정동명                               중곡동
# 지번코드               1121576000200300001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               30
# 지번주소                서울특별시 광진구 중곡동 30-1
# 도로명코드                     112153104007
# 도로명                      서울특별시 광진구 능동로
# 건물본번지                              398
# 건물관리번호       1121510100100300001000187
# 도로명주소                서울특별시 광진구 능동로 398
# 구우편번호                           143711
# 신우편번호                             4933
# 경도                             127.086
# 위도                             37.5653
# Name: 11314, dtype: object
# 상가업소번호                        21042961
# 상호명                              코아클리닉
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168063000
# 행정동명                              대치4동
# 법정동코드                      1.16801e+09
# 법정동명                               대치동
# 지번코드               1168010600208900059
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              890
# 지번주소              서울특별시 강남구 대치동 890-59
# 도로명코드                     116804166495
# 도로명                   서울특별시 강남구 선릉로86길
# 건물본번지                               31
# 건물관리번호       1168010600108900059027342
# 도로명주소              서울특별시 강남구 선릉로86길 31
# 구우편번호                           135280
# 신우편번호                             6193
# 경도                             127.052
# 위도                             37.5042
# Name: 11834, dtype: object
# 상가업소번호                        25257076
# 상호명                       한국전력공사부속한일병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11320
# 시군구명                               도봉구
# 행정동코드                       1132068000
# 행정동명                              쌍문3동
# 법정동코드                      1.13201e+09
# 법정동명                               쌍문동
# 지번코드               1132010500203880001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              388
# 지번주소               서울특별시 도봉구 쌍문동 388-1
# 도로명코드                     113203109008
# 도로명                     서울특별시 도봉구 우이천로
# 건물본번지                              308
# 건물관리번호       1132010500103880001005649
# 도로명주소               서울특별시 도봉구 우이천로 308
# 구우편번호                           132703
# 신우편번호                             1450
# 경도                             127.029
# 위도                             37.6467
# Name: 14133, dtype: object
# 상가업소번호                        21943900
# 상호명                             신촌연세병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11440
# 시군구명                               마포구
# 행정동코드                       1144063000
# 행정동명                               신수동
# 법정동코드                      1.14401e+09
# 법정동명                               신수동
# 지번코드               1144011100200710005
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               71
# 지번주소                서울특별시 마포구 신수동 71-5
# 도로명코드                     114404139292
# 도로명                   서울특별시 마포구 서강로14길
# 건물본번지                               14
# 건물관리번호       1144011100100710005007728
# 도로명주소              서울특별시 마포구 서강로14길 14
# 구우편번호                           121854
# 신우편번호                             4094
# 경도                             126.934
# 위도                             37.5524
# Name: 14928, dtype: object
# 상가업소번호                        20384548
# 상호명                           영동세브란스병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168065500
# 행정동명                              도곡1동
# 법정동코드                      1.16801e+09
# 법정동명                               도곡동
# 지번코드               1168011800201460092
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              146
# 지번주소              서울특별시 강남구 도곡동 146-92
# 도로명코드                     116803005086
# 도로명                      서울특별시 강남구 언주로
# 건물본번지                              211
# 건물관리번호       1168011800101460092026388
# 도로명주소                서울특별시 강남구 언주로 211
# 구우편번호                           135720
# 신우편번호                             6273
# 경도                             127.046
# 위도                             37.4928
# Name: 15521, dtype: object
# 상가업소번호                        24625566
# 상호명                        삼성의료재단강북삼성태
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11140
# 시군구명                                중구
# 행정동코드                       1114052000
# 행정동명                               소공동
# 법정동코드                      1.11401e+09
# 법정동명                             태평로2가
# 지번코드               1114011400202500000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              250
# 지번주소                서울특별시 중구 태평로2가 250
# 도로명코드                     111402005001
# 도로명                      서울특별시 중구 세종대로
# 건물본번지                               67
# 건물관리번호       1114011400102500000022814
# 도로명주소                 서울특별시 중구 세종대로 67
# 구우편번호                           100742
# 신우편번호                             4514
# 경도                             126.976
# 위도                             37.5624
# Name: 16678, dtype: object
# 상가업소번호                        20815937
# 상호명                          서울시립보라매병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11590
# 시군구명                               동작구
# 행정동코드                       1159068000
# 행정동명                             신대방2동
# 법정동코드                      1.15901e+09
# 법정동명                              신대방동
# 지번코드               1159010900204250000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              425
# 지번주소                서울특별시 동작구 신대방동 425
# 도로명코드                     115904160385
# 도로명                   서울특별시 동작구 보라매로5길
# 건물본번지                               20
# 건물관리번호       1159010900103950061001535
# 도로명주소              서울특별시 동작구 보라매로5길 20
# 구우편번호                           156707
# 신우편번호                             7061
# 경도                             126.924
# 위도                              37.493
# Name: 16844, dtype: object
# 상가업소번호                        26233200
# 상호명                      서울대학교병원비상계획외래
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11110
# 시군구명                               종로구
# 행정동코드                       1111064000
# 행정동명                               이화동
# 법정동코드                      1.11102e+09
# 법정동명                               연건동
# 지번코드               1111016600200280021
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               28
# 지번주소               서울특별시 종로구 연건동 28-21
# 도로명코드                     111103100002
# 도로명                      서울특별시 종로구 대학로
# 건물본번지                              101
# 건물관리번호       1111016600100280021009266
# 도로명주소                서울특별시 종로구 대학로 101
# 구우편번호                           110744
# 신우편번호                             3080
# 경도                             126.997
# 위도                             37.5804
# Name: 18818, dtype: object
# 상가업소번호                        25990790
# 상호명                       평화드림서울성모병원의료
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11650
# 시군구명                               서초구
# 행정동코드                       1165058100
# 행정동명                              반포4동
# 법정동코드                      1.16501e+09
# 법정동명                               반포동
# 지번코드               1165010700205050000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              505
# 지번주소                 서울특별시 서초구 반포동 505
# 도로명코드                     116502121003
# 도로명                     서울특별시 서초구 반포대로
# 건물본번지                              222
# 건물관리번호       1165010700101230000017226
# 도로명주소               서울특별시 서초구 반포대로 222
# 구우편번호                           137701
# 신우편번호                             6591
# 경도                             127.006
# 위도                             37.5024
# Name: 19102, dtype: object
# 상가업소번호                        20471866
# 상호명                               홍익병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11470
# 시군구명                               양천구
# 행정동코드                       1147065000
# 행정동명                              신정4동
# 법정동코드                      1.14701e+09
# 법정동명                               신정동
# 지번코드               1147010100208980007
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              898
# 지번주소               서울특별시 양천구 신정동 898-7
# 도로명코드                     114703114002
# 도로명                      서울특별시 양천구 목동로
# 건물본번지                              227
# 건물관리번호       1147010100108980007001072
# 도로명주소                서울특별시 양천구 목동로 227
# 구우편번호                           158070
# 신우편번호                             7937
# 경도                             126.864
# 위도                             37.5288
# Name: 19438, dtype: object
# 상가업소번호                        26351584
# 상호명                          사랑나눔의료재단서
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11410
# 시군구명                              서대문구
# 행정동코드                       1141056500
# 행정동명                               충현동
# 법정동코드                      1.14101e+09
# 법정동명                             충정로3가
# 지번코드               1141010200204640000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              464
# 지번주소              서울특별시 서대문구 충정로3가 464
# 도로명코드                     114103005010
# 도로명                    서울특별시 서대문구 서소문로
# 건물본번지                               21
# 건물관리번호       1141010200104640000030855
# 도로명주소               서울특별시 서대문구 서소문로 21
# 구우편번호                           120723
# 신우편번호                             3742
# 경도                             126.964
# 위도                             37.5599
# Name: 19576, dtype: object
# 상가업소번호                        22387397
# 상호명                              우신향병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11290
# 시군구명                               성북구
# 행정동코드                       1129060000
# 행정동명                               안암동
# 법정동코드                      1.12901e+09
# 법정동명                             안암동5가
# 지번코드               1129012500200860124
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               86
# 지번주소            서울특별시 성북구 안암동5가 86-124
# 도로명코드                     112903005035
# 도로명                      서울특별시 성북구 안암로
# 건물본번지                               99
# 건물관리번호       1129012500100850007040714
# 도로명주소                 서울특별시 성북구 안암로 99
# 구우편번호                           136075
# 신우편번호                             2856
# 경도                             127.031
# 위도                             37.5849
# Name: 21391, dtype: object
# 상가업소번호                         8810415
# 상호명                             동부제일병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11260
# 시군구명                               중랑구
# 행정동코드                       1126065500
# 행정동명                              망우본동
# 법정동코드                      1.12601e+09
# 법정동명                               망우동
# 지번코드               1126010500201280004
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              128
# 지번주소               서울특별시 중랑구 망우동 128-4
# 도로명코드                     112603106008
# 도로명                     서울특별시 중랑구 양원역로
# 건물본번지                                2
# 건물관리번호       1126010500101280004006657
# 도로명주소                 서울특별시 중랑구 양원역로 2
# 구우편번호                           131230
# 신우편번호                             2063
# 경도                             127.109
# 위도                             37.6008
# Name: 23422, dtype: object
# 상가업소번호                        25250287
# 상호명                           아산재단금강병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11170
# 시군구명                               용산구
# 행정동코드                       1117063000
# 행정동명                              이촌1동
# 법정동코드                      1.11701e+09
# 법정동명                               이촌동
# 지번코드               1117012900203010165
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              301
# 지번주소             서울특별시 용산구 이촌동 301-165
# 도로명코드                     111703102008
# 도로명                      서울특별시 용산구 이촌로
# 건물본번지                              318
# 건물관리번호       1117012900103010165011127
# 도로명주소                서울특별시 용산구 이촌로 318
# 구우편번호                           140030
# 신우편번호                             4425
# 경도                             126.983
# 위도                             37.5177
# Name: 24375, dtype: object
# 상가업소번호                        22490334
# 상호명                             명곡안연구소
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156053500
# 행정동명                              영등포동
# 법정동코드                      1.15601e+09
# 법정동명                            영등포동4가
# 지번코드               1156010500201230002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              123
# 지번주소           서울특별시 영등포구 영등포동4가 123-2
# 도로명코드                     115603118023
# 도로명                     서울특별시 영등포구 영신로
# 건물본번지                              136
# 건물관리번호       1156010500101560000034805
# 도로명주소               서울특별시 영등포구 영신로 136
# 구우편번호                           150034
# 신우편번호                             7301
# 경도                             126.902
# 위도                             37.5197
# Name: 25858, dtype: object
# 상가업소번호                        25314968
# 상호명                         아산재단서울중앙병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11710
# 시군구명                               송파구
# 행정동코드                       1171052000
# 행정동명                              풍납2동
# 법정동코드                      1.17101e+09
# 법정동명                               풍납동
# 지번코드               1171010300203880001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              388
# 지번주소               서울특별시 송파구 풍납동 388-1
# 도로명코드                     117104169435
# 도로명                  서울특별시 송파구 올림픽로43길
# 건물본번지                               88
# 건물관리번호       1171010300103880001024947
# 도로명주소             서울특별시 송파구 올림픽로43길 88
# 구우편번호                           138736
# 신우편번호                             5505
# 경도                             127.109
# 위도                             37.5252
# Name: 25917, dtype: object
# 상가업소번호                        24993083
# 상호명                            메디힐특수여객
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11470
# 시군구명                               양천구
# 행정동코드                       1147060000
# 행정동명                              신월5동
# 법정동코드                      1.14701e+09
# 법정동명                               신월동
# 지번코드               1147010300200510009
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               51
# 지번주소                서울특별시 양천구 신월동 51-9
# 도로명코드                     114702000003
# 도로명                    서울특별시 양천구 남부순환로
# 건물본번지                              331
# 건물관리번호       1147010300100510009010472
# 도로명주소              서울특별시 양천구 남부순환로 331
# 구우편번호                           158090
# 신우편번호                             7905
# 경도                             126.828
# 위도                             37.5373
# Name: 26291, dtype: object
# 상가업소번호                        24063170
# 상호명                        삼성생명공익재단삼성서
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168072000
# 행정동명                              일원본동
# 법정동코드                      1.16801e+09
# 법정동명                               일원동
# 지번코드               1168011400200500000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               50
# 지번주소                  서울특별시 강남구 일원동 50
# 도로명코드                     116803122009
# 도로명                      서울특별시 강남구 일원로
# 건물본번지                               81
# 건물관리번호       1168011400100500000002609
# 도로명주소                 서울특별시 강남구 일원로 81
# 구우편번호                           135710
# 신우편번호                             6351
# 경도                              127.09
# 위도                             37.4903
# Name: 27751, dtype: object
# 상가업소번호                        24670818
# 상호명                          성광의료재단차병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168064000
# 행정동명                              역삼1동
# 법정동코드                      1.16801e+09
# 법정동명                               역삼동
# 지번코드               1168010100206500009
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              650
# 지번주소               서울특별시 강남구 역삼동 650-9
# 도로명코드                     116803121022
# 도로명                      서울특별시 강남구 논현로
# 건물본번지                              566
# 건물관리번호       1168010100106500011021661
# 도로명주소                서울특별시 강남구 논현로 566
# 구우편번호                           135080
# 신우편번호                             6135
# 경도                             127.035
# 위도                             37.5068
# Name: 28248, dtype: object
# 상가업소번호                        24266526
# 상호명                        한국건강관리협회서울특
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11710
# 시군구명                               송파구
# 행정동코드                       1171071000
# 행정동명                              잠실6동
# 법정동코드                      1.17101e+09
# 법정동명                               신천동
# 지번코드               1171071000200110010
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               11
# 지번주소               서울특별시 송파구 신천동 11-10
# 도로명코드                     117103123014
# 도로명                      서울특별시 송파구 오금로
# 건물본번지                               58
# 건물관리번호       1171010200100110010000257
# 도로명주소                 서울특별시 송파구 오금로 58
# 구우편번호                           138922
# 신우편번호                             5510
# 경도                             127.105
# 위도                             37.5167
# Name: 28262, dtype: object
# 상가업소번호                        24055367
# 상호명                       정해복지부설한신메디피아
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11650
# 시군구명                               서초구
# 행정동코드                       1165058000
# 행정동명                              반포3동
# 법정동코드                      1.16501e+09
# 법정동명                               잠원동
# 지번코드               1165010600200650032
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               65
# 지번주소               서울특별시 서초구 잠원동 65-32
# 도로명코드                     116503121019
# 도로명                      서울특별시 서초구 잠원로
# 건물본번지                               88
# 건물관리번호       1165010600100650032017459
# 도로명주소                 서울특별시 서초구 잠원로 88
# 구우편번호                           137797
# 신우편번호                             6520
# 경도                             127.008
# 위도                             37.5122
# Name: 28539, dtype: object
# 상가업소번호                        22059593
# 상호명                             성베드로병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168065500
# 행정동명                              도곡1동
# 법정동코드                      1.16801e+09
# 법정동명                               도곡동
# 지번코드               1168011800209140002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              914
# 지번주소               서울특별시 강남구 도곡동 914-2
# 도로명코드                     116802000003
# 도로명                    서울특별시 강남구 남부순환로
# 건물본번지                             2633
# 건물관리번호       1168011800109150005000949
# 도로명주소             서울특별시 강남구 남부순환로 2633
# 구우편번호                           135270
# 신우편번호                             6268
# 경도                             127.038
# 위도                             37.4854
# Name: 28997, dtype: object
# 상가업소번호                        24628961
# 상호명                             성애의료재단
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156063000
# 행정동명                              신길1동
# 법정동코드                      1.15601e+09
# 법정동명                               신길동
# 지번코드               1156013200204510002
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              451
# 지번주소              서울특별시 영등포구 신길동 451-2
# 도로명코드                     115604154676
# 도로명                서울특별시 영등포구 여의대방로53길
# 건물본번지                               22
# 건물관리번호       1156013200104510005000001
# 도로명주소           서울특별시 영등포구 여의대방로53길 22
# 구우편번호                           150050
# 신우편번호                             7354
# 경도                             126.922
# 위도                              37.512
# Name: 30648, dtype: object
# 상가업소번호                        24519999
# 상호명                           Y&T성모마취과
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168058000
# 행정동명                              삼성1동
# ...
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11740
# 시군구명                               강동구
# 행정동코드                       1174064000
# 행정동명                              성내1동
# 법정동코드                      1.17401e+09
# 법정동명                               성내동
# 지번코드               1174010800205420004
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              542
# 지번주소               서울특별시 강동구 성내동 542-4
# 도로명코드                     117403124006
# 도로명                      서울특별시 강동구 성내로
# 건물본번지                               71
# 건물관리번호       1174010800105420004007127
# 도로명주소                 서울특별시 강동구 성내로 71
# 구우편번호                           134030
# 신우편번호                             5396
# 경도                             127.128
# 위도                             37.5278
# Name: 44681, dtype: object
# 상가업소번호                        22568472
# 상호명                              사랑의병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11620
# 시군구명                               관악구
# 행정동코드                       1162058500
# 행정동명                              낙성대동
# 법정동코드                      1.16201e+09
# 법정동명                               봉천동
# 지번코드               1162010100216640001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                             1664
# 지번주소              서울특별시 관악구 봉천동 1664-1
# 도로명코드                     116202000003
# 도로명                    서울특별시 관악구 남부순환로
# 건물본번지                             1860
# 건물관리번호       1162010100116640001030155
# 도로명주소             서울특별시 관악구 남부순환로 1860
# 구우편번호                           151050
# 신우편번호                             8789
# 경도                             126.956
# 위도                             37.4796
# Name: 49667, dtype: object
# 상가업소번호                        24577400
# 상호명                       성삼의료재단미즈메디병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11500
# 시군구명                               강서구
# 행정동코드                       1150061100
# 행정동명                              발산1동
# 법정동코드                      1.15001e+09
# 법정동명                              내발산동
# 지번코드               1150010600207010004
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              701
# 지번주소              서울특별시 강서구 내발산동 701-4
# 도로명코드                     115003115001
# 도로명                      서울특별시 강서구 강서로
# 건물본번지                              295
# 건물관리번호       1150010600107010031009015
# 도로명주소                서울특별시 강서구 강서로 295
# 구우편번호                           157723
# 신우편번호                             7639
# 경도                             126.836
# 위도                             37.5522
# Name: 50174, dtype: object
# 상가업소번호                        24453173
# 상호명                             씨엠충무병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156053500
# 행정동명                              영등포동
# 법정동코드                      1.15601e+09
# 법정동명                            영등포동4가
# 지번코드               1156010500200900000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               90
# 지번주소              서울특별시 영등포구 영등포동4가 90
# 도로명코드                     115604154717
# 도로명                 서울특별시 영등포구 영등포로36길
# 건물본번지                               13
# 건물관리번호       1156010500100900000035097
# 도로명주소            서울특별시 영등포구 영등포로36길 13
# 구우편번호                           150034
# 신우편번호                             7301
# 경도                             126.904
# 위도                             37.5188
# Name: 51167, dtype: object
# 상가업소번호                        22399983
# 상호명                         원진재단부설녹색병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11260
# 시군구명                               중랑구
# 행정동코드                       1126057500
# 행정동명                            면목3.8동
# 법정동코드                      1.12601e+09
# 법정동명                               면목동
# 지번코드               1126010100205680001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              568
# 지번주소               서울특별시 중랑구 면목동 568-1
# 도로명코드                     112604118367
# 도로명                  서울특별시 중랑구 사가정로49길
# 건물본번지                               53
# 건물관리번호       1126010100105680001026999
# 도로명주소             서울특별시 중랑구 사가정로49길 53
# 구우편번호                           131200
# 신우편번호                             2221
# 경도                             127.086
# 위도                             37.5836
# Name: 54845, dtype: object
# 상가업소번호                        22485607
# 상호명                            강남센트럴병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168075000
# 행정동명                               수서동
# 법정동코드                      1.16801e+09
# 법정동명                               수서동
# 지번코드               1168011500207140005
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              714
# 지번주소               서울특별시 강남구 수서동 714-5
# 도로명코드                     116804166081
# 도로명                   서울특별시 강남구 광평로51길
# 건물본번지                                6
# 건물관리번호       1168011500107140005000001
# 도로명주소             서울특별시 강남구 광평로51길 6-9
# 구우편번호                           135884
# 신우편번호                             6349
# 경도                             127.103
# 위도                             37.4884
# Name: 56967, dtype: object
# 상가업소번호                        20747548
# 상호명                              우리들병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168056500
# 행정동명                               청담동
# 법정동코드                      1.16801e+09
# 법정동명                               청담동
# 지번코드               1168010400200470004
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               47
# 지번주소                서울특별시 강남구 청담동 47-4
# 도로명코드                     116803122011
# 도로명                      서울특별시 강남구 학동로
# 건물본번지                              445
# 건물관리번호       1168010400100470004000001
# 도로명주소                서울특별시 강남구 학동로 445
# 구우편번호                           135951
# 신우편번호                             6068
# 경도                              127.05
# 위도                             37.5191
# Name: 59916, dtype: object
# 상가업소번호                         8783414
# 상호명                            건국대학교병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11215
# 시군구명                               광진구
# 행정동코드                       1121571000
# 행정동명                               화양동
# 법정동코드                      1.12151e+09
# 법정동명                               화양동
# 지번코드               1121510700200040012
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                                4
# 지번주소                서울특별시 광진구 화양동 4-12
# 도로명코드                     112153104007
# 도로명                      서울특별시 광진구 능동로
# 건물본번지                              120
# 건물관리번호       1121510700100010000016506
# 도로명주소              서울특별시 광진구 능동로 120-1
# 구우편번호                           143729
# 신우편번호                             5030
# 경도                             127.072
# 위도                             37.5412
# Name: 61398, dtype: object
# 상가업소번호                         8607388
# 상호명                            서울적십자병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11110
# 시군구명                               종로구
# 행정동코드                       1111058000
# 행정동명                               교남동
# 법정동코드                      1.11102e+09
# 법정동명                                평동
# 지번코드               1111017700201640000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              164
# 지번주소                  서울특별시 종로구 평동 164
# 도로명코드                     111103005004
# 도로명                     서울특별시 종로구 새문안로
# 건물본번지                                9
# 건물관리번호       1111017700101640000019629
# 도로명주소                 서울특별시 종로구 새문안로 9
# 구우편번호                           110747
# 신우편번호                             3181
# 경도                             126.967
# 위도                             37.5668
# Name: 61757, dtype: object
# 상가업소번호                        26515058
# 상호명                               홍익병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11470
# 시군구명                               양천구
# 행정동코드                       1147065000
# 행정동명                              신정4동
# 법정동코드                      1.14701e+09
# 법정동명                               신정동
# 지번코드               1147010100208990001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              899
# 지번주소               서울특별시 양천구 신정동 899-1
# 도로명코드                     114703114002
# 도로명                      서울특별시 양천구 목동로
# 건물본번지                              225
# 건물관리번호       1147010100108990001001152
# 도로명주소                서울특별시 양천구 목동로 225
# 구우편번호                           158738
# 신우편번호                             7937
# 경도                             126.864
# 위도                             37.5285
# Name: 71036, dtype: object
# 상가업소번호                        28505952
# 상호명                       서울성모병원응급의료센터
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11650
# 시군구명                               서초구
# 행정동코드                       1165058100
# 행정동명                              반포4동
# 법정동코드                      1.16501e+09
# 법정동명                               반포동
# 지번코드               1165010700205050000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              505
# 지번주소                 서울특별시 서초구 반포동 505
# 도로명코드                     116502121003
# 도로명                     서울특별시 서초구 반포대로
# 건물본번지                              222
# 건물관리번호       1165010700101230000017226
# 도로명주소               서울특별시 서초구 반포대로 222
# 구우편번호                           137701
# 신우편번호                             6591
# 경도                             127.006
# 위도                             37.5024
# Name: 71991, dtype: object
# 상가업소번호                        16031909
# 상호명                      가톨릭대학교여의도성모병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11140
# 시군구명                                중구
# 행정동코드                       1114055000
# 행정동명                                명동
# 법정동코드                      1.11401e+09
# 법정동명                              명동2가
# 지번코드               1114012700200010001
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                                1
# 지번주소                 서울특별시 중구 명동2가 1-1
# 도로명코드                     111404103165
# 도로명                       서울특별시 중구 명동길
# 건물본번지                               74
# 건물관리번호       1114012700100010001019574
# 도로명주소                  서울특별시 중구 명동길 74
# 구우편번호                           100809
# 신우편번호                             4537
# 경도                             126.987
# 위도                             37.5637
# Name: 90492, dtype: object
# 상가업소번호                        16332576
# 상호명                               씨엠병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11560
# 시군구명                              영등포구
# 행정동코드                       1156053500
# 행정동명                              영등포동
# 법정동코드                      1.15601e+09
# 법정동명                            영등포동4가
# 지번코드               1156010500200900000
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                               90
# 지번주소              서울특별시 영등포구 영등포동4가 90
# 도로명코드                     115604154717
# 도로명                 서울특별시 영등포구 영등포로36길
# 건물본번지                               13
# 건물관리번호       1156010500100900000035097
# 도로명주소            서울특별시 영등포구 영등포로36길 13
# 구우편번호                           150030
# 신우편번호                             7301
# 경도                             126.904
# 위도                             37.5188
# Name: 90581, dtype: object
# 상가업소번호                        16162338
# 상호명                             성베드로병원
# 상권업종대분류코드                            S
# 상권업종대분류명                            의료
# 상권업종중분류코드                          S01
# 상권업종중분류명                            병원
# 상권업종소분류코드                       S01B01
# 상권업종소분류명                          종합병원
# 시도명                              서울특별시
# 시군구코드                            11680
# 시군구명                               강남구
# 행정동코드                       1168065500
# 행정동명                              도곡1동
# 법정동코드                      1.16801e+09
# 법정동명                               도곡동
# 지번코드               1168011800209100027
# 대지구분코드                               1
# 대지구분명                               대지
# 지번본번지                              910
# 지번주소              서울특별시 강남구 도곡동 910-27
# 도로명코드                     116802000003
# 도로명                    서울특별시 강남구 남부순환로
# 건물본번지                             2649
# 건물관리번호       1168011800109100027000895
# 도로명주소             서울특별시 강남구 남부순환로 2649
# 구우편번호                           135859
# 신우편번호                             6271
# 경도                              127.04
# 위도                             37.4856
# Name: 90788, dtype: object
